# %%
velocities = [0, 27, 34, 14, 28, 25, 36, 8, 18, 0, 24, 6, 58, 46, 53, 23, 35, 22, 22, 48, 25, 37, 44, 56, 38, 25, 43, 64, 79, 83, 26, 28, 67, 66, 70, 52, 55, 70, 77, 14, 44, 43, 52, 13, 0]


# Variables
total_distance = 0
distances_over_time = [0] # Starting at 0km

# Loop
for i in range(len(velocities) - 1):

    v1 = velocities[i]
    v2 = velocities[i+1]

  # Calculate segment distance
    segment = ((v1 + v2) / 2) *(0.5/60)   #30 seconds converted to hours

    # Distance calculation
    total_distance += segment

print(f"Total Distance: {total_distance:.2f} km")
# Out:
# Total Distance: 14.15 km
